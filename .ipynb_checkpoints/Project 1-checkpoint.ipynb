# %% [markdown]
# # The Relationship Between Political Affiliation and its Impact on the Prevalence of COVID-19 Cases in US States and Counties

# %% [markdown]
# note for myself:
#
# - some comments about inaccuracy of dataset, bring it up during collab hour about whether some datapoints should be
# ommitted
# - maybe get rid of counties with no voting data?

# %% [markdown]
# ## Data cleaning and Loading

# %%
import pandas as pd
import qeds #sample data
# %matplotlib inline
# activate plot theme
import qeds
from IPython.display import display
from datetime import timezone, timedelta

# %%
county_stats = pd.read_csv(r'/Users/adieaimannazrinnoornazri/ECO225/Project Data/county_statistics.csv')
county_stats.info()
county_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4867 entries, 0 to 4866
# Data columns (total 51 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    4867 non-null   int64
#  1   county                        4867 non-null   object
#  2   state                         4867 non-null   object
#  3   percentage16_Donald_Trump     3111 non-null   float64
#  4   percentage16_Hillary_Clinton  3111 non-null   float64
#  5   total_votes16                 3111 non-null   float64
#  6   votes16_Donald_Trump          3111 non-null   float64
#  7   votes16_Hillary_Clinton       3111 non-null   float64
#  8   percentage20_Donald_Trump     4490 non-null   float64
#  9   percentage20_Joe_Biden        4490 non-null   float64
#  10  total_votes20                 4633 non-null   float64
#  11  votes20_Donald_Trump          4633 non-null   float64
# ...

# %%
county_stats.isnull().sum()
# Out:
# Unnamed: 0                         0
# county                             0
# state                              0
# percentage16_Donald_Trump       1756
# percentage16_Hillary_Clinton    1756
# total_votes16                   1756
# votes16_Donald_Trump            1756
# votes16_Hillary_Clinton         1756
# percentage20_Donald_Trump        377
# percentage20_Joe_Biden           377
# total_votes20                    234
# votes20_Donald_Trump             234
# votes20_Joe_Biden                234
# lat                             1615
# long                            1615
# cases                           1615
# deaths                          1615
# TotalPop                        1725
# Men                             1725
# Women                           1725
# Hispanic                        1725
# White                           1725
# Black                           1725
# Native                          1725
# Asian                           1725
# ...

# %% [markdown]
# ### Since some counties have no voting statistics, instead we'll fill empty data points with the median
# #### Using the median is better to account for the case of any possible outliers that can affect data analysis

# %%
county_stats.fillna(county_stats.median(numeric_only=True), inplace=True)
county_stats.__delitem__('Unnamed: 0')
county_stats
# Out:
#                           county state  percentage16_Donald_Trump  \
# 0                      Abbeville    SC                      0.629
# 1                         Acadia    LA                      0.773
# 2                       Accomack    VA                      0.545
# 3                            Ada    ID                      0.479
# 4                          Adair    IA                      0.653
# ...                          ...   ...                        ...
# 4862  Valdez-Cordova Census Area    AK                      0.667
# 4863   Wrangell City and Borough    AK                      0.667
# 4864    Yakutat City and Borough    AK                      0.667
# 4865   Yukon-Koyukuk Census Area    AK                      0.667
# 4866                    Doña Ana    NM                      0.667
#
#       percentage16_Hillary_Clinton  total_votes16  votes16_Donald_Trump  \
# 0                            0.346        10724.0                6742.0
# ...

# %%
county_stats.isnull().sum()
# Out:
# county                          0
# state                           0
# percentage16_Donald_Trump       0
# percentage16_Hillary_Clinton    0
# total_votes16                   0
# votes16_Donald_Trump            0
# votes16_Hillary_Clinton         0
# percentage20_Donald_Trump       0
# percentage20_Joe_Biden          0
# total_votes20                   0
# votes20_Donald_Trump            0
# votes20_Joe_Biden               0
# lat                             0
# long                            0
# cases                           0
# deaths                          0
# TotalPop                        0
# Men                             0
# Women                           0
# Hispanic                        0
# White                           0
# Black                           0
# Native                          0
# Asian                           0
# Pacific                         0
# VotingAgeCitizen                0
# Income                          0
# ...

# %% [markdown]
# ### Now all counties have data values with the previous missing datapoints substituted in with the median of each column, we see this in the above where there no null values anymore
#
# ### Additionally we have not lost any of our columns despite many occurences of null entries
#
# ### Moving on to the next dataset

# %%
trump_biden_polls = pd.read_csv(r'/Users/adieaimannazrinnoornazri/ECO225/Project Data/trump_biden_polls.csv')
trump_biden_polls
# Out:
# /var/folders/5k/mklfc3z159ddw6b0m8_kwp0c0000gn/T/ipykernel_67619/962960962.py:1: DtypeWarning: Columns (6,22,25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   trump_biden_polls = pd.read_csv(r'/Users/adieaimannazrinnoornazri/ECO225/Project Data/trump_biden_polls.csv')
#        question_id  poll_id  cycle         state  pollster_id  \
# 0           136283    72621   2020          Iowa          383
# 1           136283    72621   2020          Iowa          383
# 2           136322    72647   2020  Pennsylvania          461
# 3           136322    72647   2020  Pennsylvania          461
# 4           136322    72647   2020  Pennsylvania          461
# ...            ...      ...    ...           ...          ...
# 16433        92081    57026   2020          Ohio          383
# 16434        92082    57026   2020          Ohio          383
# 16435        92082    57026   2020          Ohio          383
# ...

# %%
list(trump_biden_polls.columns)
# Out:
# ['question_id',
#  'poll_id',
#  'cycle',
#  'state',
#  'pollster_id',
#  'pollster',
#  'sponsor_ids',
#  'sponsors',
#  'display_name',
#  'pollster_rating_id',
#  'pollster_rating_name',
#  'fte_grade',
#  'sample_size',
#  'population',
#  'population_full',
#  'methodology',
#  'office_type',
#  'seat_number',
#  'seat_name',
#  'start_date',
#  'end_date',
#  'election_date',
#  'sponsor_candidate',
#  'internal',
#  'partisan',
#  'tracking',
#  'nationwide_batch',
#  'ranked_choice_reallocated',
#  'created_at',
#  'notes',
#  'url',
#  'stage',
#  'race_id',
#  'answer',
#  'candidate_id',
#  'candidate_name',
#  'candidate_party',
#  'pct']

# %% [markdown]
# ### We will only keep necessary columns such as: state, sample_size, population, population_full, office_type, answer, candidate_id, candidate_name, candidate_party, pct
#
# ### We will also drop any results that have empty datapoints in the state column as it geographic location is an important indicator we need

# %%
trump_biden_polls = trump_biden_polls.dropna(subset='state')
trump_biden_polls.head(15)
# Out:
#     question_id  poll_id  cycle          state  pollster_id  \
# 0        136283    72621   2020           Iowa          383
# 1        136283    72621   2020           Iowa          383
# 2        136322    72647   2020   Pennsylvania          461
# 3        136322    72647   2020   Pennsylvania          461
# 4        136322    72647   2020   Pennsylvania          461
# 5        136491    72722   2020        Florida          235
# 6        136491    72722   2020        Florida          235
# 7        136491    72722   2020        Florida          235
# 22       136533    72754   2020  Nebraska CD-2         1613
# 23       136533    72754   2020  Nebraska CD-2         1613
# 24       136533    72754   2020  Nebraska CD-2         1613
# 25       136537    72757   2020  Nebraska CD-2         1365
# 26       136537    72757   2020  Nebraska CD-2         1365
# 27       136537    72757   2020  Nebraska CD-2         1365
# 28       136544    72762   2020        Montana         1365
#
# ...

# %% [markdown]
# ### Comparing this with the previous dataframe, all rows with empty state names have been dropped

# %%
drop_columns = ['question_id',
 'poll_id',
 'cycle',
 'pollster_id',
 'pollster',
 'sponsor_ids',
 'sponsors',
 'display_name',
 'pollster_rating_id',
 'pollster_rating_name',
 'fte_grade',
 'methodology',
 'seat_number',
 'seat_name',
 'start_date',
 'end_date',
 'election_date',
 'sponsor_candidate',
 'internal',
 'partisan',
 'tracking',
 'nationwide_batch',
 'ranked_choice_reallocated',
 'created_at',
 'notes',
 'url',
 'stage',
 'race_id',]

for columns in drop_columns:
    trump_biden_polls.__delitem__(columns)
trump_biden_polls
# Out:
#               state  sample_size population population_full     office_type  \
# 0              Iowa        871.0          v               v  U.S. President
# 1              Iowa        871.0          v               v  U.S. President
# 2      Pennsylvania        499.0         lv              lv  U.S. President
# 3      Pennsylvania        499.0         lv              lv  U.S. President
# 4      Pennsylvania        499.0         lv              lv  U.S. President
# ...             ...          ...        ...             ...             ...
# 16431          Ohio        648.0          v               v  U.S. President
# 16432          Ohio        648.0          v               v  U.S. President
# 16433          Ohio        648.0          v               v  U.S. President
# 16434          Ohio        648.0          v               v  U.S. President
# 16435          Ohio        648.0          v               v  U.S. President
#
# ...

# %%
unique_values = trump_biden_polls['candidate_name'].unique()
unique_values
# Out:
# array(['Joseph R. Biden Jr.', 'Donald Trump', 'Jo Jorgensen',
#        'Howie Hawkins', 'Kanye West', 'Don Blankenship',
#        'Roque De La Fuente', 'Jade Simmons', 'Brock Pierce',
#        'Gloria La Riva', 'Kamala D. Harris', 'Mike Pence',
#        'Alyson Kennedy', 'Jacob Hornberger', 'Justin Amash',
#        'Bernard Sanders', 'Elizabeth Warren', 'Michael Bloomberg',
#        'Pete Buttigieg', 'Amy Klobuchar', 'Tulsi Gabbard', 'Tom Steyer',
#        'Andrew Yang', 'Cory A. Booker', 'Julián Castro', "Beto O'Rourke",
#        'Nimrata R. Haley', 'Steve Bullock', 'Marianne Williamson',
#        'Oprah Winfrey', 'Michelle Obama', 'Kirsten E. Gillibrand',
#        'Bill de Blasio', 'Howard Schultz', 'Sherrod Brown',
#        'Nancy Pelosi'], dtype=object)

# %%
#trump_clinton_polls = pd.read_csv(r'/Users/adieaimannazrinnoornazri/ECO225/Project Data/trump_clinton_polls.csv')
#trump_clinton_polls

# %% [markdown]
# ## Summary Statistics Tables

# %% [markdown]
# ## Plots, Histograms, Figures

# %% [markdown]
# ## Conclusion
